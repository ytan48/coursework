# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: Highest Mountains in the World</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/highest-mountain/">https://discovery.cs.illinois.edu/microproject/highest-mountain/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Data Source: Wikipedia's "List of mountains by elevation"
#
# Wikipedia is an absolutely amazing source of information about almost every topic you can imagine!  In this MicroProject, you will explore how to easily use data in Wikipedia tables as datasets.
#
# The Wikipedia article "[List of mountains by elevation](https://en.wikipedia.org/wiki/List_of_mountains_by_elevation)" (https://en.wikipedia.org/wiki/List_of_mountains_by_elevation) contains information on hundreds of mountains -- including **Mount Everest** (tallest in the world), **Denali** (tallest in the United States), and many more!
# - Click the link above [(or right here)](https://en.wikipedia.org/wiki/List_of_mountains_by_elevation) to view how the Wikipedia page looks in your web browser!

# %% [markdown]
# ### Using pandas `read_html` function
#
# The `pd.read_html(...)` function in the pandas library is designed to read data from tables found in webpages.
# - `read_html` is very similar to the more commonly used `read_csv`
# - Instead of returning a DataFrame like `read_csv`, the `read_html` returns a **list of DataFrames -- one DataFrame for each table on the website**!
# - Just like `read_csv`, you only need to provide the URL of the data!
#
# Import `pandas` and use `pd.read_html` to create a new variable called `pages` the reads in all of tables on the Wikipedia page  "[List of mountains by elevation](https://en.wikipedia.org/wiki/List_of_mountains_by_elevation)":

# %%
import pandas as pd
pages = pd.read_html("https://en.wikipedia.org/wiki/List_of_mountains_by_elevation")
pages
# Out:
# [                          Mountain  Metres   Feet      Range  \
#  0                    Mount Everest    8848  29029  Himalayas
#  1                               K2    8611  28251  Karakoram
#  2                    Kangchenjunga    8586  28169  Himalayas
#  3                           Lhotse    8516  27940  Himalayas
#  4                           Makalu    8485  27838  Himalayas
#  5                          Cho Oyu    8188  26864  Himalayas
#  6                       Dhaulagiri    8167  26795  Himalayas
#  7                          Manaslu    8163  26781  Himalayas
#  8                     Nanga Parbat    8126  26660  Himalayas
#  9                        Annapurna    8091  26545  Himalayas
#  10  Gasherbrum I (Hidden peak; K5)    8080  26509  Karakoram
#  11                      Broad Peak    8051  26414  Karakoram
#  12              Gasherbrum II (K4)    8035  26362  Karakoram
#  13                    Shishapangma    8027  26335  Himalayas
#
#                                     Location and Notes
#  0                                         Nepal/China
#  1                                      Pakistan/China
#  2                                         Nepal/India
#  3   Nepal – Climbers ascend Lhotse Face in climbin...
#  4                                               Nepal
#  5       Nepal – Considered "easiest" eight-thousander
#  6     Nepal – Presumed world's highest from 1808-1838
#  7                                               Nepal
#  8                                            Pakistan
#  9   Nepal – First eight-thousander to be climbed (...
#  10               Pakistan/China – Originally named K5
#  11                                     Pakistan/China
#  12               Pakistan/China – Originally named K4
#  13                                              China  ,
#                 Mountain  Metres   Feet      Range  \
#  0        Gasherbrum III    7952  26089  Karakoram
#  1         Gyachung Kang    7952  26089  Himalayas
#  2          Annapurna II    7937  26040  Himalayas
#  3    Gasherbrum IV (K3)    7932  26024  Karakoram
#  4            Himalchuli    7893  25896  Himalayas
#  ..                  ...     ...    ...        ...
#  129              Saipal    7031  23068  Himalayas
#  130           Padmanabh    7030  23064  Himalayas
#  131             Spantik    7027  23054  Karakoram
#  132           Pamri Sar    7016  23018  Karakoram
#  133         Khan Tengri    7010  22999  Tian Shan
#
#                                  Location and Notes
#  0                                         Pakistan
#  1                             Nepal (Khumbu)/China
#  2                                            Nepal
#  3                                         Pakistan
#  4                                   Manaslu, Nepal
#  ..                                             ...
#  129                                          Nepal
#  130                                          India
#  131                                       Pakistan
#  132                                       Pakistan
#  133  Kyrgyzstan-Kazakhstan-China – #2 in Tian Shan
#
#  [134 rows x 5 columns],
#                           Mountain  Metres   Feet  \
#  0                    Machapuchare    6993  22943
#  1    Laila Peak (Haramosh Valley)    6985  22917
#  2                       Kang Guru    6981  22904
#  3                   Gasherbrum VI    6979  22897
#  4                       Karun Kuh    6977  22890
#  ..                            ...     ...    ...
#  112                    Tocllaraju    6034  19797
#  113                        Shayaz    6026  19770
#  114                 Hualca Hualca    6025  19767
#  115                      Uturunku    6020  19751
#  116                    Mitre Peak    6010  19718
#
#                                      Location and Notes
#  0    Annapurna Himalaya, Nepal – Officially unclimb...
#  1                                  Karakoram, Pakistan
#  2    Manaslu Himalaya, Nepal – 2005 avalanche kills 18
#  3                                  Karakoram, Pakistan
#  4                                  Karakoram, Pakistan
#  ..                                                 ...
#  112                                        Andes, Peru
#  113                               Hindu Kush, Pakistan
#  114                                        Andes, Peru
#  115                                     Andes, Bolivia
#  116                                Karakoram, Pakistan
#
#  [117 rows x 4 columns],
#          Mountain  Metres   Feet                  Range  \
#  0     Laila Peak    5971  19590               Himalaya
#  1    Mount Logan    5959  19551  Saint Elias Mountains
#  2       Alpamayo    5947  19511                  Andes
#  3    Cerro Lípez    5929  19452                  Andes
#  4     Licancabur    5920  19423                  Andes
#  ..           ...     ...    ...                    ...
#  74         Janga    5051  16572     Caucasus Mountains
#  75  Mount Kazbek    5055  16585     Caucasus Mountains
#  76    Tungurahua    5023  16480                  Andes
#  77  Carihuairazo    5018  16463                  Andes
#  78    Mount Bona    5005  16421  Saint Elias Mountains
#
#                                     Location and Notes
#  0                                            Pakistan
#  1                   Yukon, Canada – Highest in Canada
#  2                                                Peru
#  3                                             Bolivia
#  4                                       Bolivia/Chile
#  ..                                                ...
#  74  Georgia / North Caucasus, Russia – Second high...
#  75             Georgia – Third highest in the country
#  76                           Ecuador – Active volcano
#  77                                            Ecuador
#  78       Alaska, US – Also given as 5,030 m or 5,045m
#
#  [79 rows x 5 columns],
#                   Mountain  Metres   Feet  \
#  0         Mount Blackburn    4996  16391
#  1            Pico Bolívar    4981  16342
#  2             Talgar Peak    4979  16335
#  3    Shota Rustaveli Peak    4960  16273
#  4           Mount Sanford    4949  16237
#  ..                    ...     ...    ...
#  258         Twilight Peak    4010  13156
#  259           Francs Peak    4009  13153
#  260          Mount Lahili    4009  13153
#  261          Mount Walter    4005  13140
#  262           Les Droites    4000  13123
#
#                                      Location and Notes
#  0       Wrangell Mtns., Alaska, US (also given 5036 m)
#  1    Sierra Nevada de Mérida, Andes, Venezuela – Hi...
#  2    Tian Shan, Kazakhstan – Highest in northern Ti...
#  3    Caucasus Mountains, Svaneti, Georgia/North Cau...
#  4                           Wrangell Mtns., Alaska, US
#  ..                                                 ...
#  258                   San Juan Mountains, Colorado, US
#  259                        Absaroka Range, Wyoming, US
#  260                    Svaneti Range, Svaneti, Georgia
#  261                                     New Mexico, US
#  262                          Mont Blanc massif, France
#
#  [263 rows x 4 columns],
#                  Mountain  Metres   Feet  \
#  0               Piz Zupò    3995  13107
#  1           Truchas Peak    3994  13104
#  2            Fletschhorn    3993  13100
#  3    Mount Albert Edward    3990  13091
#  4               La Meije    3987  13081
#  ..                   ...     ...    ...
#  342       Cathedral Peak    3004   9856
#  343          Mount Tahat    3003   9852
#  344              Sapitwa    3002   9849
#  345          Ben Macdhui    3001   9846
#  346         The Fortress    3000   9843
#
#                           Location and Notes
#  0                Bernina Range, Switzerland
#  1    Sangre de Cristo Mountains, New Mexico
#  2                 Pennine Alps, Switzerland
#  3                          Papua New Guinea
#  4                     Dauphiné Alps, France
#  ..                                      ...
#  342                             Drakensberg
#  343                       Algeria – Highest
#  344                  Mulanje Massif, Malawi
#  345              Eastern Cape, South Africa
#  346                        Canadian Rockies
#
#  [347 rows x 4 columns],
#                   Mountain  Metres  Feet  \
#  0    Tre Cime di Lavaredo  2999.0  9839
#  1          Pizzo Centrale  2999.0  9839
#  2        Cascade Mountain  2998.0  9836
#  3                 Copahue  2997.0  9833
#  4          Mount Girouard  2985.0  9793
#  ..                    ...     ...   ...
#  301       Alpe di Succiso  2017.0  6617
#  302                   Kom  2016.0  6614
#  303       Polar Bear Peak  2016.0  6614
#  304          Mount Asgard  2015.0  6611
#  305        Mount Le Conte  2010.0  6594
#
#                              Location and Notes
#  0                   Province of Belluno, Italy
#  1                                  Switzerland
#  2    Vermilion Range, Canadian Rockies, Canada
#  3                       Andes, Argentina/Chile
#  4    Fairholme Range, Canadian Rockies, Canada
#  ..                                         ...
#  301            Province of Reggio Emilia Italy
#  302                  Balkan Mountain, Bulgaria
#  303              Chugach Mountains, Alaska, US
#  304          Baffin Mountains, Nunavut, Canada
#  305       Great Smoky Mountains, Tennessee, US
#
#  [306 rows x 4 columns],
#               Mountain  Metres  Feet                     Location and Notes
#  0    Serra da Estrela  1993.0  6539                               Portugal
#  1        Mount Bogong  1986.0  6516        Australia – Highest in Victoria
#  2     Mount Ishizuchi  1982.0  6503       Japan – Tallest in Western Japan
#  3         Doi Phu Kha  1980.0  6496          Luang Prabang Range, Thailand
#  4     Pizzo Carbonara  1979.0  6493             Province of Palermo Sicily
#  ..                ...     ...   ...                                    ...
#  225         Munboksan  1015.0  3330                            South Korea
#  226             Kékes  1014.0  3327  Hungary – Highest mountain in Hungary
#  227     Mount Belumut  1010.0  3314                        Johor, Malaysia
#  228  Old Rag Mountain  1001.0  3284                           Virginia, US
#  229      Devil's Peak  1000.0  3281                Cape Town, South Africa
#
#  [230 rows x 4 columns],
#                  Mountain  Metres  Feet                 Range  \
#  0            Sgurr Dearg   986.0  3235               Cuillin
#  1            Mount Sizer   980.0  3215          Diablo Range
#  2            Mount Valin   980.0  3215  Saguenay Lac St-Jean
#  3             Hyangnosan   979.0  3212                   NaN
#  4           Scafell Pike   978.0  3209        Southern Fells
#  ..                   ...     ...   ...                   ...
#  126  Mount Ngerchelchuus   242.0   794                   NaN
#  127          Mount Royal   233.0   764                   NaN
#  128         Diamond Head   232.0   761                   NaN
#  129            Yeomposan   203.0   666                   NaN
#  130            Hamwolsan   200.0   656                   NaN
#
#                           Location and Notes
#  0                                  Scotland
#  1                           US (California)
#  2                           Canada (Québec)
#  3           Gyeongnam Province, South Korea
#  4    England (Cumbria) – Highest in England
#  ..                                      ...
#  126        Babeldaob, Palau – Highest point
#  127                          Quebec, Canada
#  128                             US (Hawaii)
#  129                      Ulsan, South Korea
#  130                      Ulsan, South Korea
#
#  [131 rows x 5 columns]]

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Data Import
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("pages" in vars())
assert(type(pages[0]) == type(pd.DataFrame()))
assert("Feet" in pages[0])
assert("Range" in pages[1])
assert("Mountain" in pages[2])
assert("Location and Notes" in pages[3])
assert("Metres" in pages[4])
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Joining the individual DataFrames into one large DataFrame
#
# Now that you have **ALL** of the tables in the `pages` variable, we want to convert this into one large DataFrame.  However, instead of having just one DataFrame, the webpage has different tables.
#
# Let's explore the individual tables.  Using `pages[0]`, you can view the first table of data found on the Wikipedia page:

# %%
pages[0]
# Out:
#                           Mountain  Metres   Feet      Range  \
# 0                    Mount Everest    8848  29029  Himalayas
# 1                               K2    8611  28251  Karakoram
# 2                    Kangchenjunga    8586  28169  Himalayas
# 3                           Lhotse    8516  27940  Himalayas
# 4                           Makalu    8485  27838  Himalayas
# 5                          Cho Oyu    8188  26864  Himalayas
# 6                       Dhaulagiri    8167  26795  Himalayas
# 7                          Manaslu    8163  26781  Himalayas
# 8                     Nanga Parbat    8126  26660  Himalayas
# 9                        Annapurna    8091  26545  Himalayas
# 10  Gasherbrum I (Hidden peak; K5)    8080  26509  Karakoram
# 11                      Broad Peak    8051  26414  Karakoram
# 12              Gasherbrum II (K4)    8035  26362  Karakoram
# 13                    Shishapangma    8027  26335  Himalayas
#
#                                    Location and Notes
# 0                                         Nepal/China
# 1                                      Pakistan/China
# 2                                         Nepal/India
# 3   Nepal – Climbers ascend Lhotse Face in climbin...
# 4                                               Nepal
# 5       Nepal – Considered "easiest" eight-thousander
# 6     Nepal – Presumed world's highest from 1808-1838
# 7                                               Nepal
# 8                                            Pakistan
# 9   Nepal – First eight-thousander to be climbed (...
# 10               Pakistan/China – Originally named K5
# 11                                     Pakistan/China
# 12               Pakistan/China – Originally named K4
# 13                                              China

# %% [markdown]
# Using `pages[1]`, you can view the second table that was found:

# %%
pages[1]
# Out:
#                Mountain  Metres   Feet      Range  \
# 0        Gasherbrum III    7952  26089  Karakoram
# 1         Gyachung Kang    7952  26089  Himalayas
# 2          Annapurna II    7937  26040  Himalayas
# 3    Gasherbrum IV (K3)    7932  26024  Karakoram
# 4            Himalchuli    7893  25896  Himalayas
# ..                  ...     ...    ...        ...
# 129              Saipal    7031  23068  Himalayas
# 130           Padmanabh    7030  23064  Himalayas
# 131             Spantik    7027  23054  Karakoram
# 132           Pamri Sar    7016  23018  Karakoram
# 133         Khan Tengri    7010  22999  Tian Shan
#
#                                 Location and Notes
# 0                                         Pakistan
# 1                             Nepal (Khumbu)/China
# 2                                            Nepal
# 3                                         Pakistan
# 4                                   Manaslu, Nepal
# ..                                             ...
# 129                                          Nepal
# 130                                          India
# 131                                       Pakistan
# 132                                       Pakistan
# 133  Kyrgyzstan-Kazakhstan-China – #2 in Tian Shan
#
# [134 rows x 5 columns]

# %% [markdown]
# ### Finding the Last DataFrame
#
# Continue to look at the tables the Wikipedia page contains.  Find out the **last index** of `pages` that contains data about the mountains:

# %%
last_index = pages[len(pages) - 1]
last_index
# Out:
#                 Mountain  Metres  Feet                 Range  \
# 0            Sgurr Dearg   986.0  3235               Cuillin
# 1            Mount Sizer   980.0  3215          Diablo Range
# 2            Mount Valin   980.0  3215  Saguenay Lac St-Jean
# 3             Hyangnosan   979.0  3212                   NaN
# 4           Scafell Pike   978.0  3209        Southern Fells
# ..                   ...     ...   ...                   ...
# 126  Mount Ngerchelchuus   242.0   794                   NaN
# 127          Mount Royal   233.0   764                   NaN
# 128         Diamond Head   232.0   761                   NaN
# 129            Yeomposan   203.0   666                   NaN
# 130            Hamwolsan   200.0   656                   NaN
#
#                          Location and Notes
# 0                                  Scotland
# 1                           US (California)
# 2                           Canada (Québec)
# 3           Gyeongnam Province, South Korea
# 4    England (Cumbria) – Highest in England
# ..                                      ...
# 126        Babeldaob, Palau – Highest point
# 127                          Quebec, Canada
# 128                             US (Hawaii)
# 129                      Ulsan, South Korea
# 130                      Ulsan, South Korea
#
# [131 rows x 5 columns]

# %% [markdown]
# ### Combining the DataFrames Together
#
# Before we can do analysis on the whole dataset, we need to join the individual tables together.  When we join DataFrames end-to-end, where the last row of the previous DataFrame is followed by the first row of the next DataFrame, the operation is called concatenation.
#
# Read the DISCOVERY guide to learn the syntax on "Combining DataFrames by Concatenation"
# - [Guide: "Combining DataFrames by Concatenation"](https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/)
#
# Use concatenation to create a single DataFrame `df` that contains data about every mountain found on the Wikipedia page:

# %%
df = pd.concat(pages)
df
# Out:
#                 Mountain  Metres   Feet      Range  \
# 0          Mount Everest  8848.0  29029  Himalayas
# 1                     K2  8611.0  28251  Karakoram
# 2          Kangchenjunga  8586.0  28169  Himalayas
# 3                 Lhotse  8516.0  27940  Himalayas
# 4                 Makalu  8485.0  27838  Himalayas
# ..                   ...     ...    ...        ...
# 126  Mount Ngerchelchuus   242.0    794        NaN
# 127          Mount Royal   233.0    764        NaN
# 128         Diamond Head   232.0    761        NaN
# 129            Yeomposan   203.0    666        NaN
# 130            Hamwolsan   200.0    656        NaN
#
#                                     Location and Notes
# 0                                          Nepal/China
# 1                                       Pakistan/China
# 2                                          Nepal/India
# 3    Nepal – Climbers ascend Lhotse Face in climbin...
# 4                                                Nepal
# ..                                                 ...
# 126                   Babeldaob, Palau – Highest point
# 127                                     Quebec, Canada
# 128                                        US (Hawaii)
# 129                                 Ulsan, South Korea
# 130                                 Ulsan, South Korea
#
# [1621 rows x 5 columns]

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Data Merging
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("df" in vars())
assert(len(df) > len(pages[0]))
assert("Feet" in df)
assert("Mountain" in df)
assert("Hindu Kush" in df["Range"].values)
assert("K2" in df["Mountain"].values)
assert("Batura Sar" in df["Mountain"].values)
assert("Meru Peak" in df["Mountain"].values)
assert("Ubinas" in df["Mountain"].values)
assert(len(df) > 1500 and len(df) < 1650)
assert(len(df[ df["Location and Notes"].str.contains("Himalayas")]) == 35)
print(f"{tada} All Tests Passed! {tada}")
# Out:
# 🎉 All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Mountains in the United States
#
# Now that we have every mountain in a single DataFrame, we can do some analysis!  In the dataset, the `Location and Notes` column contains a human-written description of the location and other notes.
#
# Create a DataFrame called `df_us` that contains all of the mountains in the United States.
#
# - You will need to look back at the [Wikipedia page](https://en.wikipedia.org/wiki/List_of_mountains_by_elevation), or explore `df` here in Python, to find out all the different ways mountains in the United States might be labeled.  *(Hint: There's two different ways!)*

# %%
df_us = df [ df ['Location and Notes'].str.contains('United States') | df ['Location and Notes'].str.contains('Alaska') | df ['Location and Notes'].str.contains('US') |
            df ['Location and Notes'].str.contains('Hawaii')]
df_us
# Out:
#                     Mountain  Metres   Feet                  Range  \
# 97   Denali (Mount McKinley)  6190.0  20308                    NaN
# 32         Mount Saint Elias  5489.0  18009  Saint Elias Mountains
# 49             Mount Foraker  5304.0  17402           Alaska Range
# 78                Mount Bona  5005.0  16421  Saint Elias Mountains
# 0            Mount Blackburn  4996.0  16391                    NaN
# ..                       ...     ...    ...                    ...
# 89        Taum Sauk Mountain   540.0   1772                    NaN
# 96                 Little Si   480.0   1575          Cascade Range
# 106      Storm King Mountain   408.0   1339       Hudson Highlands
# 125            Jerimoth Hill   247.0    810                    NaN
# 128             Diamond Head   232.0    761                    NaN
#
#                                     Location and Notes
# 97   Alaska Range, United States (Alaska) – Highest...
# 32   Yukon, Canada/Alaska, US – Second highest in b...
# 49                                          Alaska, US
# 78        Alaska, US – Also given as 5,030 m or 5,045m
# 0       Wrangell Mtns., Alaska, US (also given 5036 m)
# ..                                                 ...
# 89                                        Missouri, US
# 96                                      Washington, US
# 106                                      US (New York)
# 125                                   Rhode Island, US
# 128                                        US (Hawaii)
#
# [347 rows x 5 columns]

# %% [markdown]
# ### Analysis: Percentage of Mountains in the Dataset in the United States?
#
# What percentage of mountains in the entire dataset are found in the United States?

# %%
pct_us = (len(df_us) / len(df))
pct_us
# Out:
# 0.21406539173349784

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Mountains
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("df_us" in vars())
assert(len(df_us) > 300 and len(df_us) < 400)
assert(len(df_us[ df_us.Mountain.str.contains("Mount Saint Elias")]) == 1)
assert(len(df_us[ df_us.Mountain.str.contains("Denali")]) == 1)
assert("Ubinas" not in df_us["Mountain"])
assert("Carihuairazo" not in df_us["Mountain"])
assert("Sirbal Peak" not in df_us["Mountain"])
assert("pct_us" in vars())
assert(pct_us == len(df_us) / len(df))

print(f"{tada} DataFrame Analysis: All Tests Passed! {tada}")
# Out:
# 🎉 DataFrame Analysis: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 Microproject - All Checkpoints 🔬
#
# The final check is that you pass all the tests, all at once!

# %%
### TEST CASE for Final Checkpoint
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"

assert("pages" in vars())
assert(type(pages[0]) == type(pd.DataFrame()))
assert("Feet" in pages[0])
assert("Range" in pages[1])
assert("Mountain" in pages[2])
assert("Location and Notes" in pages[3])
assert("Metres" in pages[4])

assert("df" in vars())
assert(len(df) > len(pages[0]))
assert("Feet" in df)
assert("Mountain" in df)
assert("Hindu Kush" in df["Range"].values)
assert("K2" in df["Mountain"].values)
assert("Batura Sar" in df["Mountain"].values)
assert("Meru Peak" in df["Mountain"].values)
assert("Ubinas" in df["Mountain"].values)
assert(len(df) > 1500 and len(df) < 1650)
assert(len(df[ df["Location and Notes"].str.contains("Himalayas")]) == 35)

assert("df_us" in vars())
assert(len(df_us) > 300 and len(df_us) < 400)
assert(len(df_us[ df_us.Mountain.str.contains("Mount Saint Elias")]) == 1)
assert(len(df_us[ df_us.Mountain.str.contains("Denali")]) == 1)
assert("Ubinas" not in df_us["Mountain"])
assert("Carihuairazo" not in df_us["Mountain"])
assert("Sirbal Peak" not in df_us["Mountain"])

assert("pct_us" in vars())
assert(pct_us == len(df_us) / len(df))

print(f"{tada}{tada} All Tests Passed! {tada}{tada}")
# Out:
# 🎉🎉 All Tests Passed! 🎉🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/highest-mountain/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
