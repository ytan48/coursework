# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject</div>
# <span style="">MicroProject: United States Congress</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/us-congress/">https://discovery.cs.illinois.edu/microproject/us-congress/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">
#
# ## Introduction
#
# In this microproject, you will use Exploratory Data Analysis (EDA) techniques and the `value_counts` function to find various statistics about the current legislators in the United States Congress.  Let's nerd out!

# %% [markdown]
# ## Dataset: "congress-legislators"
#
# The [@unitedstates project](https://theunitedstates.io/) maintains various high-quality datasets about the United States government.  Specifically, the `congress-legislators` dataset contains every member "of the United States Congress (1789-Present), congressional committees (1973-Present), committee membership (current only), and presidents and vice presidents of the United States in YAML, JSON, and CSV format."
#
# The URL for the CSV dataset is:
# ```
# https://theunitedstates.io/congress-legislators/legislators-current.csv
# ```
#
# Load the dataset into a DataFrame called `df`:

# %%
import pandas as pd
df = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
df
# Out:
#     last_name first_name middle_name suffix nickname             full_name  \
# 0       Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1    Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2      Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3      Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4       Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
# ..        ...        ...         ...    ...      ...                   ...
# 532   Kennedy    Timothy         NaN    NaN      NaN    Timothy M. Kennedy
# 533      Fong      Vince         NaN    NaN      NaN            Vince Fong
# 534     Rulli    Michael          A.    NaN      NaN      Michael A. Rulli
# 535     Lopez       Greg         NaN    NaN      NaN            Greg Lopez
# 536     Helmy     George          S.    NaN      NaN       George S. Helmy
#
#        birthday gender type state  ...  opensecrets_id  lis_id  \
# 0    1952-11-09      M  sen    OH  ...       N00003535    S307
# 1    1958-10-13      F  sen    WA  ...       N00007836    S275
# 2    1943-10-05      M  sen    MD  ...       N00001955    S308
# 3    1947-01-23      M  sen    DE  ...       N00012508    S277
# 4    1960-04-13      M  sen    PA  ...       N00027503    S309
# ..          ...    ...  ...   ...  ...             ...     ...
# 532  1976-10-20      M  rep    NY  ...             NaN     NaN
# 533  1979-10-24      M  rep    CA  ...             NaN     NaN
# 534  1969-03-11      M  rep    OH  ...             NaN     NaN
# 535  1964-06-07      M  rep    CO  ...             NaN     NaN
# 536  1979-10-27      M  sen    NJ  ...             NaN    S425
#
#                  fec_ids  cspan_id govtrack_id votesmart_id  \
# 0    H2OH13033,S6OH00163    5051.0      400050      27018.0
# 1    S8WA00194,H2WA01054   26137.0      300018      27122.0
# 2    H6MD03177,S6MD03177    4004.0      400064      26888.0
# 3              S8DE00079     663.0      300019      22421.0
# 4              S6PA00217   47036.0      412246       2541.0
# ..                   ...       ...         ...          ...
# 532            H4NY26078  134035.0      456957      91670.0
# 533            H4CA20181       NaN      456958          NaN
# 534            H4OH06165       NaN      456959          NaN
# 535            H4CO04348       NaN      456960          NaN
# 536                  NaN       NaN      456961          NaN
#
#              ballotpedia_id washington_post_id icpsr_id  \
# 0             Sherrod Brown                NaN  29389.0
# 1            Maria Cantwell                NaN  39310.0
# 2                Ben Cardin                NaN  15408.0
# 3                Tom Carper                NaN  15015.0
# 4            Bob Casey, Jr.                NaN  40703.0
# ..                      ...                ...      ...
# 532  Tim Kennedy (New York)                NaN      NaN
# 533              Vince Fong                NaN      NaN
# 534                     NaN                NaN      NaN
# 535                     NaN                NaN      NaN
# 536            George Helmy                NaN      NaN
#
#                  wikipedia_id
# 0               Sherrod Brown
# 1              Maria Cantwell
# 2                  Ben Cardin
# 3                  Tom Carper
# 4               Bob Casey Jr.
# ..                        ...
# 532  Tim Kennedy (politician)
# 533                Vince Fong
# 534             Michael Rulli
# 535                Greg Lopez
# 536              George Helmy
#
# [537 rows x 36 columns]

# %% [markdown]
# ## Show All Columns
#
# This dataset has **A LOT** of columns!  By default, pandas will not show all of them.  By setting the `display.max_columns` value, we can view all the columns:

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#     last_name first_name middle_name suffix nickname             full_name  \
# 0       Brown    Sherrod         NaN    NaN      NaN         Sherrod Brown
# 1    Cantwell      Maria         NaN    NaN      NaN        Maria Cantwell
# 2      Cardin   Benjamin          L.    NaN      NaN    Benjamin L. Cardin
# 3      Carper     Thomas     Richard    NaN      NaN      Thomas R. Carper
# 4       Casey     Robert          P.    Jr.      Bob  Robert P. Casey, Jr.
# ..        ...        ...         ...    ...      ...                   ...
# 532   Kennedy    Timothy         NaN    NaN      NaN    Timothy M. Kennedy
# 533      Fong      Vince         NaN    NaN      NaN            Vince Fong
# 534     Rulli    Michael          A.    NaN      NaN      Michael A. Rulli
# 535     Lopez       Greg         NaN    NaN      NaN            Greg Lopez
# 536     Helmy     George          S.    NaN      NaN       George S. Helmy
#
#        birthday gender type state  district  senate_class       party  \
# 0    1952-11-09      M  sen    OH       NaN           1.0    Democrat
# 1    1958-10-13      F  sen    WA       NaN           1.0    Democrat
# 2    1943-10-05      M  sen    MD       NaN           1.0    Democrat
# 3    1947-01-23      M  sen    DE       NaN           1.0    Democrat
# 4    1960-04-13      M  sen    PA       NaN           1.0    Democrat
# ..          ...    ...  ...   ...       ...           ...         ...
# 532  1976-10-20      M  rep    NY      26.0           NaN    Democrat
# 533  1979-10-24      M  rep    CA      20.0           NaN  Republican
# 534  1969-03-11      M  rep    OH       6.0           NaN  Republican
# 535  1964-06-07      M  rep    CO       4.0           NaN  Republican
# 536  1979-10-27      M  sen    NJ       NaN           1.0    Democrat
#
#                                  url  \
# 0       https://www.brown.senate.gov
# 1    https://www.cantwell.senate.gov
# 2      https://www.cardin.senate.gov
# 3      https://www.carper.senate.gov
# 4       https://www.casey.senate.gov
# ..                               ...
# 532        https://kennedy.house.gov
# 533           https://fong.house.gov
# 534          https://rulli.house.gov
# 535          https://lopez.house.gov
# 536     https://www.helmy.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 532  2269 Rayburn House Office Building Washington ...  202-225-3306
# 533  2468 Rayburn House Office Building Washington ...  202-225-2915
# 534  2082 Rayburn House Office Building Washington ...  202-225-5705
# 535  2455 Rayburn House Office Building Washington ...  202-225-4676
# 536  528 Hart Senate Office Building Washington DC ...  202-224-4744
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 532                                                NaN
# 533                                                NaN
# 534                                                NaN
# 535                                                NaN
# 536                                                NaN
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 532                                                NaN              NaN
# 533                                                NaN              NaN
# 534                                                NaN              NaN
# 535                                                NaN              NaN
# 536                                                NaN              NaN
#
#       twitter_id             facebook           youtube  \
# 0     43910797.0  SenatorSherrodBrown  SherrodBrownOhio
# 1    117501995.0      senatorcantwell   SenatorCantwell
# 2    109071031.0     senatorbencardin     senatorcardin
# 3    249787913.0            tomcarper     senatorcarper
# 4    171598736.0      SenatorBobCasey   SenatorBobCasey
# ..           ...                  ...               ...
# 532          NaN                  NaN               NaN
# 533          NaN                  NaN               NaN
# 534          NaN                  NaN               NaN
# 535          NaN                  NaN               NaN
# 536          NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 532                       NaN      NaN     K000402        NaN            NaN
# 533                       NaN      NaN     F000480        NaN            NaN
# 534                       NaN      NaN     R000619        NaN            NaN
# 535                       NaN      NaN     L000604        NaN            NaN
# 536                       NaN      NaN     H001097        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 532    NaN            H4NY26078  134035.0       456957       91670.0
# 533    NaN            H4CA20181       NaN       456958           NaN
# 534    NaN            H4OH06165       NaN       456959           NaN
# 535    NaN            H4CO04348       NaN       456960           NaN
# 536   S425                  NaN       NaN       456961           NaN
#
#              ballotpedia_id  washington_post_id  icpsr_id  \
# 0             Sherrod Brown                 NaN   29389.0
# 1            Maria Cantwell                 NaN   39310.0
# 2                Ben Cardin                 NaN   15408.0
# 3                Tom Carper                 NaN   15015.0
# 4            Bob Casey, Jr.                 NaN   40703.0
# ..                      ...                 ...       ...
# 532  Tim Kennedy (New York)                 NaN       NaN
# 533              Vince Fong                 NaN       NaN
# 534                     NaN                 NaN       NaN
# 535                     NaN                 NaN       NaN
# 536            George Helmy                 NaN       NaN
#
#                  wikipedia_id
# 0               Sherrod Brown
# 1              Maria Cantwell
# 2                  Ben Cardin
# 3                  Tom Carper
# 4               Bob Casey Jr.
# ..                        ...
# 532  Tim Kennedy (politician)
# 533                Vince Fong
# 534             Michael Rulli
# 535                Greg Lopez
# 536              George Helmy
#
# [537 rows x 36 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Splitting The House of Representatives and The Senate
#
# In this dataset, each row is one member of Congress.  The United States Congress is bicameral, being made up of both the House of Representatives and the Senate.  In the dataset:
#
# - Representatives in the House of Representatives represent a district, which is encoded in the `district` column.  Their `type` column is `rep`.
# - Senators are elected for six years, with one-third of the senators up for election every two years.  The `senate_class` denotes which election class a senator is in.  A senator's `type` column is `sen`.
#
# Create two new DataFrames, `df_house` and `df_senate`, that contain members of the House of Representatives and the Senate:

# %%
df_house = df[df['type'] == 'rep']
df_house
# Out:
#       last_name first_name middle_name suffix nickname  \
# 25     Aderholt     Robert          B.    NaN      NaN
# 28    Bilirakis        Gus          M.    NaN      NaN
# 29       Bishop    Sanford          D.    Jr.      NaN
# 31   Blumenauer       Earl         NaN    NaN      NaN
# 34     Buchanan       Vern         NaN    NaN      NaN
# ..          ...        ...         ...    ...      ...
# 531      Suozzi     Thomas          R.    NaN      NaN
# 532     Kennedy    Timothy         NaN    NaN      NaN
# 533        Fong      Vince         NaN    NaN      NaN
# 534       Rulli    Michael          A.    NaN      NaN
# 535       Lopez       Greg         NaN    NaN      NaN
#
#                   full_name    birthday gender type state  district  \
# 25       Robert B. Aderholt  1965-07-22      M  rep    AL       4.0
# 28         Gus M. Bilirakis  1963-02-08      M  rep    FL      12.0
# 29   Sanford D. Bishop, Jr.  1947-02-04      M  rep    GA       2.0
# 31          Earl Blumenauer  1948-08-16      M  rep    OR       3.0
# 34            Vern Buchanan  1951-05-08      M  rep    FL      16.0
# ..                      ...         ...    ...  ...   ...       ...
# 531        Thomas R. Suozzi  1962-08-31      M  rep    NY       3.0
# 532      Timothy M. Kennedy  1976-10-20      M  rep    NY      26.0
# 533              Vince Fong  1979-10-24      M  rep    CA      20.0
# 534        Michael A. Rulli  1969-03-11      M  rep    OH       6.0
# 535              Greg Lopez  1964-06-07      M  rep    CO       4.0
#
#      senate_class       party                           url  \
# 25            NaN  Republican    https://aderholt.house.gov
# 28            NaN  Republican   https://bilirakis.house.gov
# 29            NaN    Democrat      https://bishop.house.gov
# 31            NaN    Democrat  https://blumenauer.house.gov
# 34            NaN  Republican    https://buchanan.house.gov
# ..            ...         ...                           ...
# 531           NaN    Democrat      https://suozzi.house.gov
# 532           NaN    Democrat     https://kennedy.house.gov
# 533           NaN  Republican        https://fong.house.gov
# 534           NaN  Republican       https://rulli.house.gov
# 535           NaN  Republican       https://lopez.house.gov
#
#                                                address         phone  \
# 25   266 Cannon House Office Building Washington DC...  202-225-4876
# 28   2306 Rayburn House Office Building Washington ...  202-225-5755
# 29   2407 Rayburn House Office Building Washington ...  202-225-3631
# 31   1111 Longworth House Office Building Washingto...  202-225-4811
# 34   2110 Rayburn House Office Building Washington ...  202-225-5015
# ..                                                 ...           ...
# 531  1117 Longworth House Office Building Washingto...  202-225-3335
# 532  2269 Rayburn House Office Building Washington ...  202-225-3306
# 533  2468 Rayburn House Office Building Washington ...  202-225-2915
# 534  2082 Rayburn House Office Building Washington ...  202-225-5705
# 535  2455 Rayburn House Office Building Washington ...  202-225-4676
#
#     contact_form                                            rss_url  \
# 25           NaN  http://aderholt.house.gov/common/rss//index.cf...
# 28           NaN  http://bilirakis.house.gov/index.php?format=fe...
# 29           NaN                    http://bishop.house.gov/rss.xml
# 31           NaN  http://blumenauer.house.gov/index.php?format=f...
# 34           NaN  http://buchanan.house.gov/index.php?option=com...
# ..           ...                                                ...
# 531          NaN                                                NaN
# 532          NaN                                                NaN
# 533          NaN                                                NaN
# 534          NaN                                                NaN
# 535          NaN                                                NaN
#
#              twitter   twitter_id             facebook           youtube  \
# 25   Robert_Aderholt   76452765.0       RobertAderholt    RobertAderholt
# 28   RepGusBilirakis   26051676.0         GusBilirakis   RepGusBilirakis
# 29     SanfordBishop  249410485.0        sanfordbishop  RepSanfordBishop
# 31   BlumenauerMedia  137823987.0                  NaN     RepBlumenauer
# 34      VernBuchanan   20467163.0  CongressmanBuchanan      vernbuchanan
# ..               ...          ...                  ...               ...
# 531              NaN          NaN                  NaN               NaN
# 532              NaN          NaN                  NaN               NaN
# 533              NaN          NaN                  NaN               NaN
# 534              NaN          NaN                  NaN               NaN
# 535              NaN          NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 25   UC71CAgpg1gbLTew_pfTneGA      NaN     A000055     1460.0      N00003028
# 28   UC2z1uu1n4-60xXs5x1mvLJw      NaN     B001257     1838.0      N00027462
# 29   UCxF9veLBrkr_CqVq5eFYVGg      NaN     B000490       91.0      N00002674
# 31   UCuziVoKuGn7feNA5VrpxsBQ      NaN     B000574       99.0      N00007727
# 34   UCY4DEy41NxOTdcF8_XAVZvw      NaN     B001260     1840.0      N00027626
# ..                        ...      ...         ...        ...            ...
# 531                       NaN      NaN     S001201        NaN      N00038742
# 532                       NaN      NaN     K000402        NaN            NaN
# 533                       NaN      NaN     F000480        NaN            NaN
# 534                       NaN      NaN     R000619        NaN            NaN
# 535                       NaN      NaN     L000604        NaN            NaN
#
#     lis_id    fec_ids   cspan_id  govtrack_id  votesmart_id  \
# 25     NaN  H6AL04098    45516.0       400004         441.0
# 28     NaN  H6FL09070  1022873.0       412250       17318.0
# 29     NaN  H2GA02031    26194.0       400030       26817.0
# 31     NaN  H6OR03064    43809.0       400033         367.0
# 34     NaN  H6FL13148  1021626.0       412196       66247.0
# ..     ...        ...        ...          ...           ...
# 531    NaN  H6NY03247   104747.0       412717       92111.0
# 532    NaN  H4NY26078   134035.0       456957       91670.0
# 533    NaN  H4CA20181        NaN       456958           NaN
# 534    NaN  H4OH06165        NaN       456959           NaN
# 535    NaN  H4CO04348        NaN       456960           NaN
#
#              ballotpedia_id  washington_post_id  icpsr_id  \
# 25       Robert B. Aderholt                 NaN   29701.0
# 28         Gus M. Bilirakis                 NaN   20758.0
# 29       Sanford Bishop Jr.                 NaN   29339.0
# 31          Earl Blumenauer                 NaN   29588.0
# 34            Vern Buchanan                 NaN   20709.0
# ..                      ...                 ...       ...
# 531              Tom Suozzi                 NaN   21747.0
# 532  Tim Kennedy (New York)                 NaN       NaN
# 533              Vince Fong                 NaN       NaN
# 534                     NaN                 NaN       NaN
# 535                     NaN                 NaN       NaN
#
#                  wikipedia_id
# 25            Robert Aderholt
# 28              Gus Bilirakis
# 29             Sanford Bishop
# 31            Earl Blumenauer
# 34              Vern Buchanan
# ..                        ...
# 531             Thomas Suozzi
# 532  Tim Kennedy (politician)
# 533                Vince Fong
# 534             Michael Rulli
# 535                Greg Lopez
#
# [437 rows x 36 columns]

# %%
df_senate = df[df['type'] == 'sen']
df_senate
# Out:
#      last_name    first_name middle_name suffix nickname  \
# 0        Brown       Sherrod         NaN    NaN      NaN
# 1     Cantwell         Maria         NaN    NaN      NaN
# 2       Cardin      Benjamin          L.    NaN      NaN
# 3       Carper        Thomas     Richard    NaN      NaN
# 4        Casey        Robert          P.    Jr.      Bob
# ..         ...           ...         ...    ...      ...
# 451      Vance  J.D. (James)     (David)    NaN      NaN
# 452  Fetterman          John        Karl    NaN      NaN
# 526   Ricketts          Pete         NaN    NaN      NaN
# 528     Butler      Laphonza   Romanique    NaN      NaN
# 536      Helmy        George          S.    NaN      NaN
#
#                 full_name    birthday gender type state  district  \
# 0           Sherrod Brown  1952-11-09      M  sen    OH       NaN
# 1          Maria Cantwell  1958-10-13      F  sen    WA       NaN
# 2      Benjamin L. Cardin  1943-10-05      M  sen    MD       NaN
# 3        Thomas R. Carper  1947-01-23      M  sen    DE       NaN
# 4    Robert P. Casey, Jr.  1960-04-13      M  sen    PA       NaN
# ..                    ...         ...    ...  ...   ...       ...
# 451            J.D. Vance  1984-08-02      M  sen    OH       NaN
# 452        John Fetterman  1969-08-15      M  sen    PA       NaN
# 526         Pete Ricketts  1964-08-19      M  sen    NE       NaN
# 528    Laphonza R. Butler  1979-05-11      F  sen    CA       NaN
# 536       George S. Helmy  1979-10-27      M  sen    NJ       NaN
#
#      senate_class       party                               url  \
# 0             1.0    Democrat      https://www.brown.senate.gov
# 1             1.0    Democrat   https://www.cantwell.senate.gov
# 2             1.0    Democrat     https://www.cardin.senate.gov
# 3             1.0    Democrat     https://www.carper.senate.gov
# 4             1.0    Democrat      https://www.casey.senate.gov
# ..            ...         ...                               ...
# 451           3.0  Republican      https://www.vance.senate.gov
# 452           3.0    Democrat  https://www.fetterman.senate.gov
# 526           2.0  Republican   https://www.ricketts.senate.gov
# 528           1.0    Democrat     https://www.butler.senate.gov
# 536           1.0    Democrat      https://www.helmy.senate.gov
#
#                                                address         phone  \
# 0    503 Hart Senate Office Building Washington DC ...  202-224-2315
# 1    511 Hart Senate Office Building Washington DC ...  202-224-3441
# 2    509 Hart Senate Office Building Washington DC ...  202-224-4524
# 3    513 Hart Senate Office Building Washington DC ...  202-224-2441
# 4    393 Russell Senate Office Building Washington ...  202-224-6324
# ..                                                 ...           ...
# 451  288 Russell Senate Office Building Washington ...  202-224-3353
# 452  142 Russell Senate Office Building Washington ...  202-224-4254
# 526  139 Russell Senate Office Building Washington ...  202-224-4224
# 528  112 Hart Senate Office Building Washington DC ...  202-224-3841
# 536  528 Hart Senate Office Building Washington DC ...  202-224-4744
#
#                                           contact_form  \
# 0                https://www.brown.senate.gov/contact/
# 1    https://www.cantwell.senate.gov/public/index.c...
# 2               https://www.cardin.senate.gov/contact/
# 3               https://www.carper.senate.gov/contact/
# 4                 https://www.casey.senate.gov/contact
# ..                                                 ...
# 451              https://www.vance.senate.gov/contact/
# 452          https://www.fetterman.senate.gov/contact/
# 526           https://www.ricketts.senate.gov/contact/
# 528  https://www.butler.senate.gov/share-your-opinion/
# 536                                                NaN
#
#                                                rss_url          twitter  \
# 0    http://www.brown.senate.gov/rss/feeds/?type=al...  SenSherrodBrown
# 1    http://www.cantwell.senate.gov/public/index.cf...  SenatorCantwell
# 2     http://www.cardin.senate.gov/rss/feeds/?type=all    SenatorCardin
# 3    http://www.carper.senate.gov/public/index.cfm/...    SenatorCarper
# 4           http://www.casey.senate.gov/rss/feeds/?all      SenBobCasey
# ..                                                 ...              ...
# 451                                                NaN              NaN
# 452                                                NaN              NaN
# 526                                                NaN              NaN
# 528                                                NaN              NaN
# 536                                                NaN              NaN
#
#       twitter_id             facebook           youtube  \
# 0     43910797.0  SenatorSherrodBrown  SherrodBrownOhio
# 1    117501995.0      senatorcantwell   SenatorCantwell
# 2    109071031.0     senatorbencardin     senatorcardin
# 3    249787913.0            tomcarper     senatorcarper
# 4    171598736.0      SenatorBobCasey   SenatorBobCasey
# ..           ...                  ...               ...
# 451          NaN                  NaN               NaN
# 452          NaN                  NaN               NaN
# 526          NaN                  NaN               NaN
# 528          NaN                  NaN               NaN
# 536          NaN                  NaN               NaN
#
#                    youtube_id mastodon bioguide_id  thomas_id opensecrets_id  \
# 0    UCgy8jfERh-t_ixkKKoCmglQ      NaN     B000944      136.0      N00003535
# 1    UCN52UDqKgvHRk39ncySrIMw      NaN     C000127      172.0      N00007836
# 2    UCiQaJnMzlfzzG3VESgyZChA      NaN     C000141      174.0      N00001955
# 3    UCgLnvbKwu4B3navofj6Qvvw      NaN     C000174      179.0      N00012508
# 4    UCtVssXhx-KuZa-hSvnsnJ0A      NaN     C001070     1828.0      N00027503
# ..                        ...      ...         ...        ...            ...
# 451                       NaN      NaN     V000137        NaN      N00048832
# 452                       NaN      NaN     F000479        NaN      N00038201
# 526                       NaN      NaN     R000618        NaN      N00027695
# 528                       NaN      NaN     B001320        NaN            NaN
# 536                       NaN      NaN     H001097        NaN            NaN
#
#     lis_id              fec_ids  cspan_id  govtrack_id  votesmart_id  \
# 0     S307  H2OH13033,S6OH00163    5051.0       400050       27018.0
# 1     S275  S8WA00194,H2WA01054   26137.0       300018       27122.0
# 2     S308  H6MD03177,S6MD03177    4004.0       400064       26888.0
# 3     S277            S8DE00079     663.0       300019       22421.0
# 4     S309            S6PA00217   47036.0       412246        2541.0
# ..     ...                  ...       ...          ...           ...
# 451   S421            S2OH00436       NaN       456876           NaN
# 452   S418            S6PA00274       NaN       456877      166286.0
# 526   S423            S6NE00129   61233.0       456952       57777.0
# 528   S424                  NaN       NaN       456954           NaN
# 536   S425                  NaN       NaN       456961           NaN
#
#       ballotpedia_id  washington_post_id  icpsr_id     wikipedia_id
# 0      Sherrod Brown                 NaN   29389.0    Sherrod Brown
# 1     Maria Cantwell                 NaN   39310.0   Maria Cantwell
# 2         Ben Cardin                 NaN   15408.0       Ben Cardin
# 3         Tom Carper                 NaN   15015.0       Tom Carper
# 4     Bob Casey, Jr.                 NaN   40703.0    Bob Casey Jr.
# ..               ...                 ...       ...              ...
# 451       J.D. Vance                 NaN       NaN      J. D. Vance
# 452   John Fetterman                 NaN       NaN   John Fetterman
# 526    Pete Ricketts                 NaN       NaN    Pete Ricketts
# 528  Laphonza Butler                 NaN       NaN  Laphonza Butler
# 536     George Helmy                 NaN       NaN     George Helmy
#
# [100 rows x 36 columns]

# %% [markdown]
# ## 🔬 MicroProject Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 1: Splitting The House of Representatives and The Senate
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
assert( len(df) > 500 ), "Your DataFrame `df` appears to not be the full dataset?  Did you modify `df` instead of creating a new `df_house` or `df_senate`?"
assert( len(df_senate) <= 100 ), "Your DataFrame `df_senate` contains more than 100 rows, but there should be 100 (or fewer) senators."
assert( len(df_house) == len(df) - len(df_senate) ), "Your DataFrame `df_house` does not contain everyone who isn't in the senate."
print(f"{tada} Puzzle 1: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 1: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Find the Controlling Party of the House of Representatives
#
# In each body of Congress, the "controlling party" is the party that has the majority of the members.
#
# ### Using the `value_counts` function:
#
# To find a count of the unique values for one column, the `value_counts` function will provide a count for each unique value.
#
# For example:
#
# ```py
# # Returns the number of members of congress (`df`) for each unique value in the column "type":
# df.value_counts("type")
# # type
# # rep   438
# # sen   100
#
# # Returns the number of senators (`df_state`) for each unique value in the column "state":
# df_senate.value_counts("state")
# # state
# # AK    2
# # PA    2
# # ND    2
# # NE    2
# # ...and so on, for all 50 states...
# ```
#
# Using `value_counts`, create a variable `political_party_count` that counts the number of members in each political party **in ONLY the House of Representatives**:

# %%
political_party_count = df_house.value_counts("party")
political_party_count
# Out:
# party
# Republican    223
# Democrat      214
# Name: count, dtype: int64

# %% [markdown]
# ### Puzzle 2 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, fill out the following cell with the number of Democrats and Republications:

# %%
democrats_in_house = 214
republicans_in_house = 223

# %% [markdown]
# ### 🔬 Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 2: Find the Controlling Party of the House of Representatives
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
R = df[ df.party == "Republican" ].head(1).index[0]
D = df[ df.party == "Democrat" ].head(1).index[0]
assert(len(political_party_count) == 2)
assert((political_party_count.index[0] == "Democrat" or political_party_count.index[0] == "Republican" or "party" in df.columns.tolist()))
assert(df_house.groupby("party").agg("count").loc["Democrat"].max() == democrats_in_house)
assert(df_house.groupby("party").agg("count").loc["Republican"].max() == republicans_in_house)
print(f"{tada} Puzzle 2: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 2: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Find the Youngest Member of each Party in the House of Representatives
#
# In the House of Representatives, who is the youngest Democrat and who is the youngest Republican?
#
# **HINT**: To help with this, the `sort_values` function may be useful!  See our guide: ["Sorting a DataFrame Using Pandas"](https://discovery.cs.illinois.edu/guides/Modifying-DataFrames/sorting-a-dataframe-with-pandas/) to learn how to use the `sort_values` function.  You will be able to use the `sort_values` function to help solve this problem! :)

# %%
df.sort_values('birthday')
# Out:
#          last_name  first_name middle_name suffix nickname  \
# 68        Grassley     Charles          E.    NaN    Chuck
# 114     Napolitano       Grace          F.    NaN      NaN
# 116         Norton     Eleanor      Holmes    NaN      NaN
# 124         Rogers      Harold         NaN    NaN      Hal
# 156         Waters      Maxine         NaN    NaN      NaN
# ..             ...         ...         ...    ...      ...
# 387         Jacobs        Sara         NaN    NaN      NaN
# 519          Casar    Gregorio     Eduardo    NaN      NaN
# 466   Paulina Luna        Anna   (Paulina)    NaN      NaN
# 340  Ocasio-Cortez  Alexandria         NaN    NaN      NaN
# 465          Frost     Maxwell   Alejandro    NaN      NaN
#
#                     full_name    birthday gender type state  district  \
# 68             Chuck Grassley  1933-09-17      M  sen    IA       NaN
# 114       Grace F. Napolitano  1936-12-04      F  rep    CA      31.0
# 116     Eleanor Holmes Norton  1937-06-13      F  rep    DC       0.0
# 124             Harold Rogers  1937-12-31      M  rep    KY       5.0
# 156             Maxine Waters  1938-08-15      F  rep    CA      43.0
# ..                        ...         ...    ...  ...   ...       ...
# 387               Sara Jacobs  1989-02-01      F  rep    CA      51.0
# 519                Greg Casar  1989-05-04      M  rep    TX      35.0
# 466         Anna Paulina Luna  1989-05-06      F  rep    FL      13.0
# 340  Alexandria Ocasio-Cortez  1989-10-13      F  rep    NY      14.0
# 465             Maxwell Frost  1997-01-17      M  rep    FL      10.0
#
#      senate_class       party                              url  \
# 68            3.0  Republican  https://www.grassley.senate.gov
# 114           NaN    Democrat     https://napolitano.house.gov
# 116           NaN    Democrat         https://norton.house.gov
# 124           NaN  Republican      https://halrogers.house.gov
# 156           NaN    Democrat         https://waters.house.gov
# ..            ...         ...                              ...
# 387           NaN    Democrat     https://sarajacobs.house.gov
# 519           NaN    Democrat          https://casar.house.gov
# 466           NaN  Republican           https://luna.house.gov
# 340           NaN    Democrat  https://ocasio-cortez.house.gov
# 465           NaN    Democrat          https://frost.house.gov
#
#                                                address         phone  \
# 68   135 Hart Senate Office Building Washington DC ...  202-224-3744
# 114  1610 Longworth House Office Building Washingto...  202-225-5256
# 116  2136 Rayburn House Office Building Washington ...  202-225-8050
# 124  2406 Rayburn House Office Building Washington ...  202-225-4601
# 156  2221 Rayburn House Office Building Washington ...  202-225-2201
# ..                                                 ...           ...
# 387  1314 Longworth House Office Building Washingto...  202-225-2040
# 519  1339 Longworth House Office Building Washingto...  202-225-5645
# 466  1017 Longworth House Office Building Washingto...  202-225-5961
# 340  250 Cannon House Office Building Washington DC...  202-225-3965
# 465  1224 Longworth House Office Building Washingto...  202-225-2176
#
#                                 contact_form  \
# 68   https://www.grassley.senate.gov/contact
# 114                                      NaN
# 116                                      NaN
# 124                                      NaN
# 156                                      NaN
# ..                                       ...
# 387                                      NaN
# 519                                      NaN
# 466                                      NaN
# 340                                      NaN
# 465                                      NaN
#
#                                                rss_url          twitter  \
# 68    http://grassley.senate.gov/customcf/rss_feed.cfm    ChuckGrassley
# 114                http://napolitano.house.gov/rss.xml  GraceNapolitano
# 116  http://norton.house.gov/index.php?format=feed&...    EleanorNorton
# 124           http://halrogers.house.gov/news/rss.aspx     RepHalRogers
# 156              http://waters.house.gov/news/rss.aspx  RepMaxineWaters
# ..                                                 ...              ...
# 387                                                NaN    RepSaraJacobs
# 519                                                NaN         RepCasar
# 466                                                NaN          RepLuna
# 340                                                NaN           RepAOC
# 465                                                NaN  RepMaxwellFrost
#
#        twitter_id              facebook             youtube  \
# 68   1.061523e+07              grassley    senchuckgrassley
# 114  1.614111e+08    RepGraceNapolitano  RepGraceNapolitano
# 116  2.360026e+07   CongresswomanNorton      EleanorHNorton
# 124  5.504018e+08  CongressmanHalRogers        RepHalRogers
# 156  3.668604e+07          MaxineWaters        MaxineWaters
# ..            ...                   ...                 ...
# 387  1.345104e+18                   NaN                 NaN
# 519  1.499512e+18                   NaN                 NaN
# 466  1.610231e+18                   NaN                 NaN
# 340  1.079105e+18                   NaN                 NaN
# 465  1.608494e+18                   NaN                 NaN
#
#                    youtube_id                              mastodon  \
# 68   UCiCPRkcLMInpDeOqGkMTt4w                                   NaN
# 114  UCPWjmiAIR04oQ8QMoOWcDtA                                   NaN
# 116  UChRrAXUGylfxJjbquC6aUjQ  @CongresswomanNorton@Mastodon.social
# 124  UChVFKLZkRoHQDhp4zNvEezQ                                   NaN
# 156  UCOQ2js1VYFlo74n7Ns8WsLQ                                   NaN
# ..                        ...                                   ...
# 387                       NaN                                   NaN
# 519                       NaN                                   NaN
# 466                       NaN                                   NaN
# 340                       NaN                                   NaN
# 465                       NaN                                   NaN
#
#     bioguide_id  thomas_id opensecrets_id lis_id    fec_ids  cspan_id  \
# 68      G000386      457.0      N00001758   S153  S0IA00028    1167.0
# 114     N000179     1602.0      N00006789    NaN  H8CA34068   57873.0
# 116     N000147      868.0      N00001692    NaN  H0DC00058     882.0
# 124     R000395      977.0      N00003473    NaN  H0KY05015    6739.0
# 156     W000187     1205.0      N00006690    NaN  H4CA23011    1953.0
# ..          ...        ...            ...    ...        ...       ...
# 387     J000305        NaN      N00042081    NaN  H8CA49074       NaN
# 519     C001131        NaN      N00049855    NaN  H2TX35144       NaN
# 466     L000596        NaN      N00045228    NaN  H0FL13158       NaN
# 340     O000172        NaN      N00041162    NaN  H8NY15148       NaN
# 465     F000476        NaN      N00049075    NaN  H2FL10259       NaN
#
#      govtrack_id  votesmart_id            ballotpedia_id  washington_post_id  \
# 68        300048       53293.0            Chuck Grassley                 NaN
# 114       400290        8393.0          Grace Napolitano                 NaN
# 116       400295         775.0                       NaN                 NaN
# 124       400340       26875.0             Harold Rogers                 NaN
# 156       400422       26759.0             Maxine Waters                 NaN
# ..           ...           ...                       ...                 ...
# 387       456804           NaN                       NaN                 NaN
# 519       456945      161953.0                       NaN                 NaN
# 466       456891      191344.0         Anna Paulina Luna                 NaN
# 340       412804      180416.0  Alexandria Ocasio-Cortez                 NaN
# 465       456890      209096.0                       NaN                 NaN
#
#      icpsr_id              wikipedia_id
# 68    14226.0            Chuck Grassley
# 114   29903.0          Grace Napolitano
# 116       NaN     Eleanor Holmes Norton
# 124   14854.0                Hal Rogers
# 156   29106.0             Maxine Waters
# ..        ...                       ...
# 387       NaN               Sara Jacobs
# 519       NaN                Greg Casar
# 466       NaN         Anna Paulina Luna
# 340   21949.0  Alexandria Ocasio-Cortez
# 465       NaN             Maxwell Frost
#
# [537 rows x 36 columns]

# %% [markdown]
# ### Puzzle 3 Analysis: How many Democrats and Republicans in the House?
#
# Using the result above, provide the **full name** (look for the column `full_name`) of the youngest Democrat and Republican:

# %%
youngest_democrat_in_house = "Maxwell Frost"
youngest_republican_in_house = "Anna Paulina Luna"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 MicroProject Checkpoint Tests 🔬

# %%
### TEST CASE for Puzzle 3: Find the Youngest Member of each Party in the House of Representatives
#
# What is this cell?
# - This cell contains test cases for the MicroProject. Even though you can modify this
#   cell, you should treat it like it's a read-only cell since it will be replaced with
#   a fresh version when your code is checked.
#
# - If this cell runs without any error in the output, you PASSED all test cases!
#   We try and make these test cases as useful and complete as possible, but there is
#   a chance your code may be incorrect even though you pass the test cases (these
#   tests should be seen as a way to give you confidence that code you believe is
#   actually correct, not as a robust check to catch all possible errors).
#
# - If this cell results in any errors, check you previous cells, make changes, and
#   RE-RUN your code and then re-run this cell.  Keep repeating this until the cell
#   passed with no errors! :)

tada = "\N{PARTY POPPER}"
assert(df[ df.party == "Democrat" ].sort_values(df.columns.tolist()[6]).tail(1).values[0][5] == youngest_democrat_in_house)
assert(df[ df.party == "Republican" ].sort_values(df.columns.tolist()[6]).tail(1).values[0][5] == youngest_republican_in_house)
print(f"{tada} Puzzle 3: All Tests Passed! {tada}")
# Out:
# 🎉 Puzzle 3: All Tests Passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and return to https://discovery.cs.illinois.edu/microproject/us-congress/ and complete the section **"Commit and Grade Your Notebook"**.
#
# 3. If you see a 100% grade result on your GitHub Action, you've completed this MicroProject! 🎉
